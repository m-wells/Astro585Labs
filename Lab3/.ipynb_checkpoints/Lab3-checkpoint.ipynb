# %% [markdown]
# ## 2

# %% [markdown]
# ### 2a

# %%
# generate a vector (1-d Array) of 1024 Float64 numbers
x=rand(1024);

# %%
# initialize an empty array to hold writetimes
writetime=zeros(Float64,10);
for i=1:10
    # print this vector to STDOUT and time how long it takes
    writetime[i]=@elapsed(print(STDOUT,x));
end

# take avg of writetimes
stdout_time=mean(writetime)
# Out:
# .15008349989201641
# .701432124400678
# .2331731788245801
# .6355890341734551
# .04059231724179235
# .48497989419415566
# .12814412560048694
# .6425085537017436
# .6196272914315666
# .913219190374734
# .6180522653206624
# .8792294882753597
# .17526085446580253
# .3753280297870729
# .62122943387889
# .770309838963918
# .6160040389303978
# .4944448199360916
# .5165748135650521
# .4466385904854666
# .7631407976234903
# .2001417817687965
# .5222470608140002
# .783697134325932
# .8044633377570256
# .20602260638107395
# .5665955924617387
# .7694237093484468
# .3830856544702945
# .005478767544254026
# .49211661578066335
# .3547068253689898
# .43334152243461466
# .5391441000666897
# .29531265270986173
# .0941967380928086
# .45685492109541737
# .7858301791751601
# .5126710809126891
# .32866124550215003
# .7594133007392447
# .2908581688834886
# .6005292719040249
# .04862448562858046
# .3751475848846597
# .5869872439982144
# .8520653379099157
# .7966200211992247
# .3279920247705992
# ...

# %%
print("Print time to STDOUT: ",stdout_time," seconds")
# Out:
# Print time to STDOUT: 0.
# 0133888232 seconds

# %% [markdown]
# ### 2b

# %%
# load ASCII Read/Write routines
include("ioascii.jl");

# %% [markdown]
# ### 2c

# %%
file="ascii_vector_test.txt";

# initialize an empty array to hold writetimes
writetime=zeros(Float64,10);
for i=1:10
    # write x to file and time how long it takes
    writetime[i]=@elapsed(asciiWrite(file,x));
end

# take avg of writetimes
writetime_asciiVector=mean(writetime)
print("Write time to file: ",writetime_asciiVector," seconds.\n")

# compare the writetime to the stdout_time
if writetime_asciiVector < stdout_time
    print("This is ",stdout_time/writetime_asciiVector," times faster than STDOUT.")
else
    print("This is ",writetime_asciiVector/stdout_time," times slower than STDOUT.")
end
# Out:
# Write time to file: 0.
# 0071247989 seconds.
# This is 1.8791861199057844 times faster than STDOUT.

# %%
# initialize an empty array to hold readtimes
readtime=zeros(Float64,10);
runnumber=linspace(1,10,10);
for i=1:10
    readtime[i]=@elapsed(asciiRead(file));
end
readtime_asciiVector=mean(readtime[2:10]);

# %%
using PyPlot;
plot(runnumber,readtime,color="red");
xlabel("Run Number");
ylabel("Time to read in seconds");
# Out:
# Loading help data...
# Figure(PyObject <matplotlib.figure.Figure object at 0x67fcf10>)

# %% [markdown]
# The above plot shows that the first read from the file requires much more time than the subsequent runs. The time to read again is negligible compare to the first read.

# %% [markdown]
# #### Increase the array size to 1024 by 1024

# %%
# generate a 1024 by 1024 array of Float64 numbers
x=rand(1024,1024);

# %%
# print this vector to STDOUT and time how long it takes
# THIS CAN TAKE A LONG TIME, I DON'T THINK MY BROWSER LIKES THIS
# stdout_time=@elapsed(print(STDOUT,x))

# %%
# print("Print time to STDOUT: ",stdout_time," seconds")

# %%
file="ascii_matrix_test.txt";

# initialize an empty array to hold writetimes
writetime=zeros(Float64,10);
for i=1:10
    # write x to file and time how long it takes
    writetime[i]=@elapsed(asciiWrite(file,x));
end

# take avg of writetimes
writetime_asciiArray=mean(writetime)
print("Write time to file: ",writetime_asciiArray," seconds.\n")

# compare the writetime to the stdout_time
#if writetime < stdout_time
#    print("This is ",stdout_time/writetime," times faster than STDOUT.")
#else
#    print("This is ",writetime/stdout_time," times slower than STDOUT.")
#end
# Out:
# Write time to file: 0.
# 44529593050000005 seconds.

# %%
# initialize an empty array to hold readtimes
readtime=zeros(Float64,10);
runnumber=linspace(1,10,10);
for i=1:10
    readtime[i]=@elapsed(asciiRead(file));
end
readtime_asciiArray=mean(readtime[2:10]);

# %%
using PyPlot;
plot(runnumber,readtime,color="red");
xlabel("Run Number");
ylabel("Time to read in seconds");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x79cce10>)

# %% [markdown]
# ### 2d

# %%
# load Binary Read/Write routines
include("iobinary.jl");

# generate a vector (1-d Array) of 1024 Float64 numbers
x=rand(1024);

# %%
file="binary_vector_test.txt";

# initialize an empty array to hold writetimes
writetime=zeros(Float64,10);
for i=1:10
    # write x to file and time how long it takes
    writetime[i]=@elapsed(binaryWrite(file,x));
end

# take avg of writetimes
writetime_binaryVector=mean(writetime)
print("Write time to file: ",writetime_binaryVector," seconds.\n")
# Out:
# Write time to file: 0.
# 024031497000000002 seconds.

# %%
# initialize an empty array to hold readtimes
readtime=zeros(Float64,10);
runnumber=linspace(1,10,10);
for i=1:10
    readtime[i]=@elapsed(binaryRead(file));
end
readtime_binaryVector=mean(readtime[2:10]);

# %%
using PyPlot;
plot(runnumber,readtime,color="red");
xlabel("Run Number");
ylabel("Time to read in seconds");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x8161190>)

# %% [markdown]
# #### Increase the array size to 1024 by 1024

# %%
# generate a 1024 by 1024 array of Float64 numbers
x=rand(1024,1024);

# %%
file="binary_matrix_test.txt";

# initialize an empty array to hold writetimes
writetime=zeros(Float64,10);
for i=1:10
    # write x to file and time how long it takes
    writetime[i]=@elapsed(binaryWrite(file,x));
end

# take avg of writetimes
writetime_binaryArray=mean(writetime)
print("Write time to file: ",writetime_binaryArray," seconds.\n")
# Out:
# Write time to file: 0.
# 0727120832 seconds.

# %%
# initialize an empty array to hold readtimes
readtime=zeros(Float64,10);
runnumber=linspace(1,10,10);
for i=1:10
    readtime[i]=@elapsed(binaryRead(file));
end
readtime_binaryArray=mean(readtime[2:10]);

# %%
using PyPlot;
plot(runnumber,readtime,color="red");
xlabel("Run Number");
ylabel("Time to read in seconds");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x8155190>)

# %% [markdown]
# #### run times

# %%
print("Read time ASCII vector: ",readtime_asciiVector," seconds.\n")
print("Read time binary vector: ",readtime_binaryVector," seconds.\n")
print("Read time ASCII matrix: ",readtime_asciiArray," seconds.\n")
print("Read time binary matrix: ",readtime_binaryArray," seconds.\n")
# Out:
# Read time ASCII vector: 0.
# 0008463527777777778 seconds.
# Read time binary vector: 1.7200666666666666e-5 seconds.
# Read time ASCII matrix: 1.3369201874444443 seconds.
# Read time binary matrix: 0.0027435734444444444 seconds.

# %%
print("Write time ASCII vector: ",writetime_asciiVector," seconds.\n")
print("Write time binary vector: ",writetime_binaryVector," seconds.\n")
print("Write time ASCII matrix: ",writetime_asciiArray," seconds.\n")
print("Write time binary matrix: ",writetime_binaryArray," seconds.\n")
# Out:
# Write time ASCII vector: 0.
# 0071247989 seconds.
# Write time binary vector: 0.024031497000000002 seconds.
# Write time ASCII matrix: 0.44529593050000005 seconds.
# Write time binary matrix: 0.0727120832 seconds.

# %% [markdown]
# It is apparent that the binary format is all around the best format to use. It is only outperformed in write speed when the amount of data is small. For tasks that would require multiple reads for these files it is obivous that binary storage is preferred. Note: these read speeds do not factor in the first run that incurs overhead as this is a one time effect and would not be representative of the performance in the high access limit.

# %% [markdown]
# #### file sizes

# %%
aV_file=stat("ascii_vector_test.txt");
bV_file=stat("binary_vector_test.txt");
aA_file=stat("ascii_matrix_test.txt");
bA_file=stat("binary_matrix_test.txt");

# %%
print("size of ASCII vector file is ",aV_file.size," bytes.\n")
print("size of binary vector file is ",bV_file.size," bytes.\n")
print("size of ASCII matrix file is ",aA_file.size," bytes.\n")
print("size of binary matrix file is ",bA_file.size," bytes.\n")
# Out:
# size of ASCII vector file is 18686
#  bytes.
# size of binary vector file is 8224 bytes.
# size of ASCII matrix file is 19157408 bytes.
# size of binary matrix file is 8388667 bytes.

# %% [markdown]
# We can see here that the binary file types are less than half the size of the ASCII files which is yet another reason binary storage is better than ASCII.

# %% [markdown]
# ### 2e

# %%
using HDF5,JLD;

# %%
# load HDF5 Read/Write routines
include("iohdf5.jl");
# generate a vector (1-d Array) of 1024 Float64 numbers
x=rand(1024);

# %%
file="hdf5_vector_test.txt";

# initialize an empty array to hold writetimes
writetime=zeros(Float64,10);
for i=1:10
    # write x to file and time how long it takes
    writetime[i]=@elapsed(hdf5Write(file,x));
end

# take avg of writetimes
writetime_hdf5Vector=mean(writetime)
print("Write time to file: ",writetime_hdf5Vector," seconds.\n")
# Out:
# Write time to file: 0.
# 0378602602 seconds.

# %%
# initialize an empty array to hold readtimes
readtime=zeros(Float64,10);
runnumber=linspace(1,10,10);
for i=1:10
    readtime[i]=@elapsed(hdf5Read(file));
end
readtime_hdf5Vector=mean(readtime[2:10]);

# %%
using PyPlot;
plot(runnumber,readtime,color="red");
xlabel("Run Number");
ylabel("Time to read in seconds");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7c72250>)

# %% [markdown]
# #### Increase the array size to 1024 by 1024

# %%
# generate a 1024 by 1024 array of Float64 numbers
x=rand(1024,1024);

# %%
file="hdf5_matrix_test.txt";
 
# initialize an empty array to hold writetimes
writetime=zeros(Float64,10);
for i=1:10
    # write x to file and time how long it takes
    writetime[i]=@elapsed(hdf5Write(file,x));
end
 
# take avg of writetimes
writetime_hdf5Array=mean(writetime)
print("Write time to file: ",writetime_hdf5Array," seconds.\n")
# Out:
# Write time to file: 0.
# 0423820537 seconds.

# %%
# initialize an empty array to hold readtimes
readtime=zeros(Float64,10);
runnumber=linspace(1,10,10);
for i=1:10
    readtime[i]=@elapsed(hdf5Read(file));
end
readtime_hdf5Array=mean(readtime[2:10]);

# %%
using PyPlot;
plot(runnumber,readtime,color="red");
xlabel("Run Number");
ylabel("Time to read in seconds");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x856dd10>)

# %% [markdown]
# #### run times

# %%
print("Read time ASCII vector: ",readtime_asciiVector," seconds.\n")
print("Read time binary vector: ",readtime_binaryVector," seconds.\n")
print("Read time HDF5 vector: ",readtime_hdf5Vector," seconds.\n")
print("Read time ASCII matrix: ",readtime_asciiArray," seconds.\n")
print("Read time binary matrix: ",readtime_binaryArray," seconds.\n")
print("Read time HDF5 matrix: ",readtime_hdf5Array," seconds.\n")
# Out:
# Read time ASCII vector: 0.
# 0008463527777777778 seconds.
# Read time binary vector: 1.7200666666666666e-5 seconds.
# Read time HDF5 vector: 0.002071558222222222 seconds.
# Read time ASCII matrix: 1.3369201874444443 seconds.
# Read time binary matrix: 0.0027435734444444444 seconds.
# Read time HDF5 matrix: 0.007753969555555556 seconds.

# %%
print("Write time ASCII vector: ",writetime_asciiVector," seconds.\n")
print("Write time binary vector: ",writetime_binaryVector," seconds.\n")
print("Write time HDF5 vector: ",writetime_hdf5Vector," seconds.\n")
print("Write time ASCII matrix: ",writetime_asciiArray," seconds.\n")
print("Write time binary matrix: ",writetime_binaryArray," seconds.\n")
print("Write time HDF5 matrix: ",writetime_hdf5Array," seconds.\n")
# Out:
# Write time ASCII vector: 0.
# 0071247989 seconds.
# Write time binary vector: 0.024031497000000002 seconds.
# Write time HDF5 vector: 0.0378602602 seconds.
# Write time ASCII matrix: 0.44529593050000005 seconds.
# Write time binary matrix: 0.0726515762 seconds.
# Write time HDF5 matrix: 0.0423820537 seconds.

# %% [markdown]
# #### file sizes

# %%
aV_file=stat("ascii_vector_test.txt");
bV_file=stat("binary_vector_test.txt");
hV_file=stat("hdf5_vector_test.txt");
aA_file=stat("ascii_matrix_test.txt");
bA_file=stat("binary_matrix_test.txt");
hA_file=stat("hdf5_matrix_test.txt");

# %%
print("size of ASCII vector file is ",aV_file.size," bytes.\n")
print("size of binary vector file is ",bV_file.size," bytes.\n")
print("size of hdf5 vector file is ",hV_file.size," bytes.\n")
print("size of ASCII matrix file is ",aA_file.size," bytes.\n")
print("size of binary matrix file is ",bA_file.size," bytes.\n")
print("size of hdf5 matrix file is ",hA_file.size," bytes.\n")
# Out:
# size of ASCII vector file is 18686
#  bytes.
# size of binary vector file is 8224 bytes.
# size of hdf5 vector file is 10848 bytes.
# size of ASCII matrix file is 19157408 bytes.
# size of binary matrix file is 8388667 bytes.
# size of hdf5 matrix file is 8391264 bytes.

# %% [markdown]
# In terms of read/write time, the HDF5 is not as fast as binary but it is still better than ASCII. The file size is on the order of the binary files.
